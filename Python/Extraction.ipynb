# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Get Data

# %%
ivies = ['Columbia University in the City of New York', 'Harvard University','Princeton University',
        'Yale University', 'University of Pennsylvania', 'Cornell University', 'Dartmouth College','Brown University']

# %%
df96 = pd.read_csv('MERGED1996_97_PP.csv')
df97 = pd.read_csv('MERGED1997_98_PP.csv')
df98 = pd.read_csv('MERGED1998_99_PP.csv')
df99 = pd.read_csv('MERGED1999_00_PP.csv')
df00 = pd.read_csv('MERGED2000_01_PP.csv')
df01 = pd.read_csv('MERGED2001_02_PP.csv')
df02 = pd.read_csv('MERGED2002_03_PP.csv')
df03 = pd.read_csv('MERGED2003_04_PP.csv')
df04 = pd.read_csv('MERGED2004_05_PP.csv')
df05 = pd.read_csv('MERGED2005_06_PP.csv')
df06 = pd.read_csv('MERGED2006_07_PP.csv')
df07 = pd.read_csv('MERGED2007_08_PP.csv')
df08 = pd.read_csv('MERGED2008_09_PP.csv')
df09 = pd.read_csv('MERGED2009_10_PP.csv')
df10 = pd.read_csv('MERGED2010_11_PP.csv')
df11 = pd.read_csv('MERGED2011_12_PP.csv')
df12 = pd.read_csv('MERGED2012_13_PP.csv')
df13 = pd.read_csv('MERGED2013_14_PP.csv')
df14 = pd.read_csv('MERGED2014_15_PP.csv')
df15 = pd.read_csv('MERGED2015_16_PP.csv')
df16 = pd.read_csv('MERGED2016_17_PP.csv')
df17 = pd.read_csv('MERGED2017_18_PP.csv')
df18 = pd.read_csv('MERGED2018_19_PP.csv')
# Out:
# C:\Users\zhiyu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (1,442,1407,1408,1411,1412,1413,1426,1431,1432,1433,1437,1438,1445,1446,1447,1503,1517,1520,1523,1524,1529,1530,1532,1537,1538,1539,1540,1541,1542,1605,1606,1608,1610,1611,1613,1614,1615,1616,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1708) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\zhiyu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (1,6,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\zhiyu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (1547,1575,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
idx = []
for i in range(8):
    idx.append(df96.index[df96['INSTNM'] == ivies[i]][0])

df96[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("96.xlsx")
output96 = df96[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output96['year'] = 1996

# %%
idx = []
for i in range(8):
    idx.append(df97.index[df97['INSTNM'] == ivies[i]][0])

df97[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel('97.xlsx')
output97 = df97[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output97['year'] = 1997

# %%
idx = []
for i in range(8):
    idx.append(df98.index[df98['INSTNM'] == ivies[i]][0])

df98[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("98.xlsx")
output98 = df98[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output98['year'] = 1998

# %%
idx = []
for i in range(8):
    idx.append(df99.index[df99['INSTNM'] == ivies[i]][0])

df99[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("99.xlsx")
output99 = df99[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output99['year'] = 1999

# %%
idx = []
for i in range(8):
    idx.append(df00.index[df00['INSTNM'] == ivies[i]][0])

df00[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("00.xlsx")
output00 = df00[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output00['year'] = 2000

# %%
idx = []
for i in range(8):
    idx.append(df01.index[df01['INSTNM'] == ivies[i]][0])

df01[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("01.xlsx")
output01 = df01[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output01['year'] = 2001

# %%
idx = []
for i in range(8):
    idx.append(df02.index[df02['INSTNM'] == ivies[i]][0])

df02[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("02.xlsx")
output02 = df02[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output02['year'] = 2002

# %%
idx = []
for i in range(8):
    idx.append(df03.index[df03['INSTNM'] == ivies[i]][0])

df03[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("03.xlsx")
output03 = df03[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output03['year'] = 2003

# %%
idx = []
for i in range(8):
    idx.append(df04.index[df04['INSTNM'] == ivies[i]][0])

df04[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("04.xlsx")
output04 = df04[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output04['year'] = 2004

# %%
idx = []
for i in range(8):
    idx.append(df05.index[df05['INSTNM'] == ivies[i]][0])

df05[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("05.xlsx")
output05 = df05[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output05['year'] = 2005

# %%
idx = []
for i in range(8):
    idx.append(df06.index[df06['INSTNM'] == ivies[i]][0])

df06[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("06.xlsx")
output06 = df06[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output06['year'] = 2006

# %%
idx = []
for i in range(8):
    idx.append(df07.index[df07['INSTNM'] == ivies[i]][0])

df07[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("07.xlsx")
output07 = df07[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output07['year'] = 2007

# %%
idx = []
for i in range(8):
    idx.append(df08.index[df08['INSTNM'] == ivies[i]][0])

df08[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("08.xlsx")
output08 = df08[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output08['year'] = 2008

# %%
idx = []
for i in range(8):
    idx.append(df09.index[df09['INSTNM'] == ivies[i]][0])

df09[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("09.xlsx")
output09 = df09[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output09['year'] = 2009

# %%
idx = []
for i in range(8):
    idx.append(df10.index[df10['INSTNM'] == ivies[i]][0])

df10[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("10.xlsx")
output10 = df10[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output10['year'] = 2010

# %%
idx = []
for i in range(8):
    idx.append(df11.index[df11['INSTNM'] == ivies[i]][0])

df11[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("11.xlsx")
output11 = df11[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output11['year'] = 2011

# %%
idx = []
for i in range(8):
    idx.append(df12.index[df12['INSTNM'] == ivies[i]][0])

df12[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("12.xlsx")
output12 = df12[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output12['year'] = 2012

# %%
idx = []
for i in range(8):
    idx.append(df13.index[df13['INSTNM'] == ivies[i]][0])

df13[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("13.xlsx")
output13 = df13[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output13['year'] = 2013

# %%
idx = []
for i in range(8):
    idx.append(df14.index[df14['INSTNM'] == ivies[i]][0])

df14[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("14.xlsx")
output14 = df14[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output14['year'] = 2014

# %%
idx = []
for i in range(8):
    idx.append(df15.index[df15['INSTNM'] == ivies[i]][0])

df15[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("15.xlsx")
output15 = df15[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output15['year'] = 2015

# %%
idx = []
for i in range(8):
    idx.append(df16.index[df16['INSTNM'] == ivies[i]][0])

df16[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("16.xlsx")
output16 = df16[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output16['year'] = 2016

# %%
idx = []
for i in range(8):
    idx.append(df17.index[df17['INSTNM'] == ivies[i]][0])

df17[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("17.xlsx")
output17 = df17[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output17['year'] = 2017

# %%
idx = []
for i in range(8):
    idx.append(df18.index[df18['INSTNM'] == ivies[i]][0])

df18[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx].to_excel("18.xlsx")
output18 = df18[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
output18['year'] = 2018

# %%
pd.concat([output96, output97, output98, output99, output00, output01, output02,
          output03, output04, output05, output06, output07, output08, output09,
          output10, output11, output12, output13, output14, output15, output16, output17, output18], ignore_index=True)
# Out:
#                                           INSTNM INC_PCT_LO INC_PCT_M1  \
# 0    Columbia University in the City of New York        NaN        NaN
# 1                             Harvard University        NaN        NaN
# 2                           Princeton University        NaN        NaN
# 3                                Yale University        NaN        NaN
# 4                     University of Pennsylvania        NaN        NaN
# ..                                           ...        ...        ...
# 179                              Yale University        NaN        NaN
# 180                   University of Pennsylvania        NaN        NaN
# 181                           Cornell University        NaN        NaN
# 182                            Dartmouth College        NaN        NaN
# 183                             Brown University        NaN        NaN
#
#     INC_PCT_M2 INC_PCT_H1 INC_PCT_H2  year
# 0          NaN        NaN        NaN  1996
# ...

# %%
compiled = pd.concat([output97, output98, output99, output00, output01, output02,
          output03, output04, output05, output06, output07, output08, output09,
          output10, output11, output12, output13, output14, output15, output16], ignore_index=True)
compiled
# Out:
#                                           INSTNM    INC_PCT_LO    INC_PCT_M1  \
# 0    Columbia University in the City of New York  0.4695569015  0.1093401339
# 1                             Harvard University   0.404451683  0.1004343105
# 2                           Princeton University  0.1293969849  0.0891959799
# 3                                Yale University  0.2672340426  0.0978723404
# 4                     University of Pennsylvania  0.2173469388  0.0959183673
# ..                                           ...           ...           ...
# 155                              Yale University   0.317373461  0.2051983584
# 156                   University of Pennsylvania  0.3986847513   0.152486642
# 157                           Cornell University  0.2418020227  0.1176831137
# 158                            Dartmouth College  0.2845188285  0.1223849372
# 159                             Brown University   0.206185567  0.1134020619
#
# ...

# %%
compiled.to_excel("compiled.xlsx")

# %% [markdown]
# ## Sample Code

# %%
df = pd.read_csv("MERGED2015_16_PP.csv")
df['INC_PCT_LO']
# Out:
# 0            0.6217241379
# 1             0.434823441
# 2            0.7805755396
# 3            0.3992411467
# 4            0.6269245953
#               ...
# 7661                  0.6
# 7662         0.7135135135
# 7663         0.7520547945
# 7664         0.7777777778
# 7665    PrivacySuppressed
# Name: INC_PCT_LO, Length: 7666, dtype: object

# %%
df.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_FULLTIME_POOLED_SUPP  OMENRYP_PARTTIME_POOLED_SUPP  \
# 0                           NaN                           NaN
# ...

# %%
df[["INC_PCT_LO"]]
# Out:
#              INC_PCT_LO
# 0          0.6217241379
# 1           0.434823441
# 2          0.7805755396
# 3          0.3992411467
# 4          0.6269245953
# ...                 ...
# 7661                0.6
# 7662       0.7135135135
# 7663       0.7520547945
# 7664       0.7777777778
# 7665  PrivacySuppressed
#
# [7666 rows x 1 columns]

# %%
df[['INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']]
# Out:
#              INC_PCT_LO         INC_PCT_M1         INC_PCT_M2  \
# 0          0.6217241379       0.1717241379       0.1031034483
# 1           0.434823441       0.1609691961       0.1410593539
# 2          0.7805755396       0.1330935252       0.0467625899
# 3          0.3992411467       0.1429173693       0.1391231029
# 4          0.6269245953       0.1673904461       0.1058033952
# ...                 ...                ...                ...
# 7661                0.6       0.1368421053       0.1368421053
# 7662       0.7135135135       0.1081081081       0.1135135135
# 7663       0.7520547945       0.1164383562       0.0780821918
# 7664       0.7777777778       0.1468253968  PrivacySuppressed
# 7665  PrivacySuppressed  PrivacySuppressed  PrivacySuppressed
#
#              INC_PCT_H1         INC_PCT_H2
# 0          0.0610344828       0.0424137931
# 1          0.1239669421       0.1391810669
# 2     PrivacySuppressed  PrivacySuppressed
# 3          0.1370151771        0.181703204
# ...

# %%
ivies = ['Columbia University in the City of New York', 'Harvard University','Princeton University',
        'Yale University', 'University of Pennsylvania', 'Cornell University', 'Dartmouth College','Brown University']

idx = []
for i in range(8):
    idx.append(df.index[df['INSTNM'] == ivies[i]][0])

# %%
idx
# Out:
# [2352, 1637, 2238, 661, 3279, 2360, 2146, 3362]

# %%
save = df[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
save
# Out:
#                                            INSTNM    INC_PCT_LO    INC_PCT_M1  \
# 2352  Columbia University in the City of New York  0.4702209414  0.1301633045
# 1637                           Harvard University  0.4614733277  0.1989839119
# 2238                         Princeton University  0.3456221198  0.2181259601
# 661                               Yale University  0.2959309494  0.1787916153
# 3279                   University of Pennsylvania  0.4135916359  0.1365313653
# 2360                           Cornell University  0.2517060367  0.1149606299
# 2146                            Dartmouth College  0.3063314711  0.1154562384
# 3362                             Brown University  0.2082397004  0.1280898876
#
#         INC_PCT_M2    INC_PCT_H1    INC_PCT_H2
# 2352  0.1243996158  0.0840537944  0.1911623439
# 1637  0.1414055885  0.0440304826  0.1541066892
# 2238  0.2242703533   0.044546851  0.1674347158
# 661   0.1467324291   0.085080148  0.2934648582
# ...

# %%
save['year'] = 2015
save
# Out:
#                                            INSTNM    INC_PCT_LO    INC_PCT_M1  \
# 2352  Columbia University in the City of New York  0.4702209414  0.1301633045
# 1637                           Harvard University  0.4614733277  0.1989839119
# 2238                         Princeton University  0.3456221198  0.2181259601
# 661                               Yale University  0.2959309494  0.1787916153
# 3279                   University of Pennsylvania  0.4135916359  0.1365313653
# 2360                           Cornell University  0.2517060367  0.1149606299
# 2146                            Dartmouth College  0.3063314711  0.1154562384
# 3362                             Brown University  0.2082397004  0.1280898876
#
#         INC_PCT_M2    INC_PCT_H1    INC_PCT_H2  year
# 2352  0.1243996158  0.0840537944  0.1911623439  2015
# 1637  0.1414055885  0.0440304826  0.1541066892  2015
# 2238  0.2242703533   0.044546851  0.1674347158  2015
# 661   0.1467324291   0.085080148  0.2934648582  2015
# ...

# %%
save2 = df14[['INSTNM','INC_PCT_LO', 'INC_PCT_M1', 'INC_PCT_M2','INC_PCT_H1', 'INC_PCT_H2']].loc[idx]
save2['year'] = 2014
save2
# Out:
#                                            INSTNM    INC_PCT_LO    INC_PCT_M1  \
# 2427  Columbia University in the City of New York   0.460960334   0.132776618
# 1694                           Harvard University  0.4452614379  0.1928104575
# 2312                         Princeton University  0.3497757848  0.2107623318
# 693                               Yale University  0.2668360864  0.1766200762
# 3371                   University of Pennsylvania  0.3838789376  0.1380481779
# 2435                           Cornell University  0.2602504297  0.1237417137
# 2218                            Dartmouth College   0.283269962  0.0950570342
# 3455                             Brown University  0.2183988764  0.1242977528
#
#         INC_PCT_M2    INC_PCT_H1    INC_PCT_H2  year
# 2427   0.132776618  0.0801670146  0.1933194154  2014
# 1694  0.1429738562  0.0555555556  0.1633986928  2014
# 2312  0.2227204783  0.0448430493  0.1718983558  2014
# 693   0.1639135959  0.0749682338  0.3176620076  2014
# ...

# %%
pd.concat([save, save2], ignore_index=True)
# Out:
#                                          INSTNM    INC_PCT_LO    INC_PCT_M1  \
# 0   Columbia University in the City of New York  0.4702209414  0.1301633045
# 1                            Harvard University  0.4614733277  0.1989839119
# 2                          Princeton University  0.3456221198  0.2181259601
# 3                               Yale University  0.2959309494  0.1787916153
# 4                    University of Pennsylvania  0.4135916359  0.1365313653
# 5                            Cornell University  0.2517060367  0.1149606299
# 6                             Dartmouth College  0.3063314711  0.1154562384
# 7                              Brown University  0.2082397004  0.1280898876
# 8   Columbia University in the City of New York   0.460960334   0.132776618
# 9                            Harvard University  0.4452614379  0.1928104575
# 10                         Princeton University  0.3497757848  0.2107623318
# ...
